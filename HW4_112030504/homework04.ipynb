# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/HW4/yolov7
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/HW4/yolov7

# %% [markdown]
# Download data from drive and put in {your_drive_path}/yolov7/data/
#
# [TODO]
# write two TODO functions in {your_drive_path}/yolov7/data/pre_process.py
#
# 1. split_train_val_path --> You need to split all image paths to train and validation in Q1, Q2, and Q3.
#
# 2. select_images --> You need to finish this function to chose better images in Q2 and Q3.

# %%
from os import listdir
from os.path import isfile, isdir, join
files = listdir('./data/CityCam/Q3/410')
for i in range(200):
  route='./data/CityCam/Q3/410/'+files[i]
  # !python detect.py --source "$route" --save-txt --save-conf
# Out:
# Namespace(weights='yolov7.pt', source='./data/CityCam/Q3/410/410-20160704-18-000080.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=True, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 2023-11-22 torch 2.1.0+cu118 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
import shutil
from os import listdir
from os.path import isfile, isdir, join
files = listdir('./runs/detect')
dst = './data/CityCam/Q3/410'
for i in range(200):
  temp = './runs/detect/'+files[i]+'/labels'
  print(temp)
  files2 = listdir(temp)
  src='./runs/detect/'+files[i]+'/labels/'+files2[0]
  print(src)
  dst = './data/CityCam/Q3/410/'+files2[0]
  print(dst)
  shutil.copyfile(src, dst)
# Out:
# ./runs/detect/exp/labels
# ./runs/detect/exp/labels/410-20160704-18-000080.txt
# ./data/CityCam/Q3/410/410-20160704-18-000080.txt
# ./runs/detect/exp2/labels
# ./runs/detect/exp2/labels/410-20160429-12-000006.txt
# ./data/CityCam/Q3/410/410-20160429-12-000006.txt
# ./runs/detect/exp3/labels
# ./runs/detect/exp3/labels/410-20160429-12-000192.txt
# ./data/CityCam/Q3/410/410-20160429-12-000192.txt
# ./runs/detect/exp4/labels
# ./runs/detect/exp4/labels/410-20160430-18-000240.txt
# ./data/CityCam/Q3/410/410-20160430-18-000240.txt
# ./runs/detect/exp5/labels
# ./runs/detect/exp5/labels/410-20160503-18-000038.txt
# ./data/CityCam/Q3/410/410-20160503-18-000038.txt
# ./runs/detect/exp6/labels
# ./runs/detect/exp6/labels/410-20160704-12-000129.txt
# ./data/CityCam/Q3/410/410-20160704-12-000129.txt
# ./runs/detect/exp7/labels
# ./runs/detect/exp7/labels/410-20160502-18-000265.txt
# ./data/CityCam/Q3/410/410-20160502-18-000265.txt
# ./runs/detect/exp8/labels
# ...

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q3'
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q3')
# ...

# %%
# training command
# !python train.py --project runs/train/Q3 --name refine
# Out:
# 2023-12-06 06:57:06.768639: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 06:57:06.768728: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 06:57:06.768773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 06:57:06.779681: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --project runs/train/Q3 --name refine --freeze 0 2

# %%
# !python train.py --project runs/train/Q3 --name refine --hyp data/hyp.scratch.custom.yaml
# Out:
# 2023-12-03 10:13:44.236114: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 10:13:44.236244: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 10:13:44.236294: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 10:13:44.251297: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3/refine6/weights/best.pt" --project runs/test/Q3 --name refine
# Out:
# Namespace(weights=['./runs/train/Q3/refine6/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3', name='refine', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-22 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...
